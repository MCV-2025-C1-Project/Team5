# %%
import os
os.chdir("..")

# %%
from src.data import extract
from src.visualization import plots
from src.descriptors import gray_level_histogram

# %%
image_filepath = "data/raw/BBDD/bbdd_00000.jpg"

# %%
img = extract.read_image(image_filepath)
plots.display_image(img)

# %%
img_gray = gray_level_histogram.convert_img_to_gray_scale(img)
plots.display_image(img_gray)

# %%
hist, bin_edges = gray_level_histogram.compute_histogram(img_gray)
plots.display_histogram(hist, bin_edges)

# %%
image_filepath = "data/raw/BBDD/bbdd_00001.jpg"

# %%
img = extract.read_image(image_filepath)
plots.display_image(img)

# %%
img_gray = gray_level_histogram.convert_img_to_gray_scale(img)
plots.display_image(img_gray)

# %%
hist, bin_edges = gray_level_histogram.compute_histogram(img_gray)
plots.display_histogram(hist, bin_edges)

# %%
image_filepath = "data/raw/BBDD/bbdd_00045.jpg"

# %%
img = extract.read_image(image_filepath)
plots.display_image(img)

# %%
img_gray = gray_level_histogram.convert_img_to_gray_scale(img)
plots.display_image(img_gray)

# %%
hist, bin_edges = gray_level_histogram.compute_histogram(img_gray)
plots.display_histogram(hist, bin_edges)
